# %%
# Install the required packages
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch in c:\users\82102\anaconda3\lib\site-packages (from -r requirements.txt (line 1)) (2.6.0)
# Requirement already satisfied: transformers in c:\users\82102\anaconda3\lib\site-packages (from -r requirements.txt (line 2)) (4.50.0)
# Requirement already satisfied: datasets in c:\users\82102\anaconda3\lib\site-packages (from -r requirements.txt (line 3)) (3.4.1)
# Requirement already satisfied: tiktoken in c:\users\82102\anaconda3\lib\site-packages (from -r requirements.txt (line 4)) (0.9.0)
# Requirement already satisfied: wandb in c:\users\82102\anaconda3\lib\site-packages (from -r requirements.txt (line 5)) (0.19.8)
# Requirement already satisfied: tqdm in c:\users\82102\anaconda3\lib\site-packages (from -r requirements.txt (line 6)) (4.66.5)
# Requirement already satisfied: filelock in c:\users\82102\anaconda3\lib\site-packages (from torch->-r requirements.txt (line 1)) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\82102\anaconda3\lib\site-packages (from torch->-r requirements.txt (line 1)) (4.11.0)
# Requirement already satisfied: networkx in c:\users\82102\anaconda3\lib\site-packages (from torch->-r requirements.txt (line 1)) (3.3)
# Requirement already satisfied: jinja2 in c:\users\82102\anaconda3\lib\site-packages (from torch->-r requirements.txt (line 1)) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\82102\anaconda3\lib\site-packages (from torch->-r requirements.txt (line 1)) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\82102\anaconda3\lib\site-packages (from torch->-r requirements.txt (line 1)) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\82102\anaconda3\lib\site-packages (from torch->-r requirements.txt (line 1)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\82102\anaconda3\lib\site-packages (from sympy==1.13.1->torch->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in c:\users\82102\anaconda3\lib\site-packages (from transformers->-r requirements.txt (line 2)) (0.29.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\82102\anaconda3\lib\site-packages (from transformers->-r requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\82102\anaconda3\lib\site-packages (from transformers->-r requirements.txt (line 2)) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\82102\anaconda3\lib\site-packages (from transformers->-r requirements.txt (line 2)) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\82102\anaconda3\lib\site-packages (from transformers->-r requirements.txt (line 2)) (2024.9.11)
# Requirement already satisfied: requests in c:\users\82102\anaconda3\lib\site-packages (from transformers->-r requirements.txt (line 2)) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\82102\anaconda3\lib\site-packages (from transformers->-r requirements.txt (line 2)) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\82102\anaconda3\lib\site-packages (from transformers->-r requirements.txt (line 2)) (0.5.3)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\82102\anaconda3\lib\site-packages (from datasets->-r requirements.txt (line 3)) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\82102\anaconda3\lib\site-packages (from datasets->-r requirements.txt (line 3)) (0.3.8)
# Requirement already satisfied: pandas in c:\users\82102\anaconda3\lib\site-packages (from datasets->-r requirements.txt (line 3)) (2.2.2)
# Requirement already satisfied: xxhash in c:\users\82102\anaconda3\lib\site-packages (from datasets->-r requirements.txt (line 3)) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\82102\anaconda3\lib\site-packages (from datasets->-r requirements.txt (line 3)) (0.70.16)
# Requirement already satisfied: aiohttp in c:\users\82102\anaconda3\lib\site-packages (from datasets->-r requirements.txt (line 3)) (3.10.5)
# Requirement already satisfied: click!=8.0.0,>=7.1 in c:\users\82102\anaconda3\lib\site-packages (from wandb->-r requirements.txt (line 5)) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in c:\users\82102\anaconda3\lib\site-packages (from wandb->-r requirements.txt (line 5)) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in c:\users\82102\anaconda3\lib\site-packages (from wandb->-r requirements.txt (line 5)) (3.1.43)
# Requirement already satisfied: platformdirs in c:\users\82102\anaconda3\lib\site-packages (from wandb->-r requirements.txt (line 5)) (3.10.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in c:\users\82102\anaconda3\lib\site-packages (from wandb->-r requirements.txt (line 5)) (4.25.3)
# Requirement already satisfied: psutil>=5.0.0 in c:\users\82102\anaconda3\lib\site-packages (from wandb->-r requirements.txt (line 5)) (5.9.0)
# Requirement already satisfied: pydantic<3,>=2.6 in c:\users\82102\anaconda3\lib\site-packages (from wandb->-r requirements.txt (line 5)) (2.8.2)
# Requirement already satisfied: sentry-sdk>=2.0.0 in c:\users\82102\anaconda3\lib\site-packages (from wandb->-r requirements.txt (line 5)) (2.24.0)
# Requirement already satisfied: setproctitle in c:\users\82102\anaconda3\lib\site-packages (from wandb->-r requirements.txt (line 5)) (1.3.5)
# Requirement already satisfied: colorama in c:\users\82102\anaconda3\lib\site-packages (from tqdm->-r requirements.txt (line 6)) (0.4.6)
# Requirement already satisfied: six>=1.4.0 in c:\users\82102\anaconda3\lib\site-packages (from docker-pycreds>=0.4.0->wandb->-r requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\82102\anaconda3\lib\site-packages (from aiohttp->datasets->-r requirements.txt (line 3)) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\82102\anaconda3\lib\site-packages (from aiohttp->datasets->-r requirements.txt (line 3)) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\82102\anaconda3\lib\site-packages (from aiohttp->datasets->-r requirements.txt (line 3)) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\82102\anaconda3\lib\site-packages (from aiohttp->datasets->-r requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\82102\anaconda3\lib\site-packages (from aiohttp->datasets->-r requirements.txt (line 3)) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\82102\anaconda3\lib\site-packages (from aiohttp->datasets->-r requirements.txt (line 3)) (1.11.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\82102\anaconda3\lib\site-packages (from gitpython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 5)) (4.0.7)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\82102\anaconda3\lib\site-packages (from pydantic<3,>=2.6->wandb->-r requirements.txt (line 5)) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\82102\anaconda3\lib\site-packages (from pydantic<3,>=2.6->wandb->-r requirements.txt (line 5)) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\82102\anaconda3\lib\site-packages (from requests->transformers->-r requirements.txt (line 2)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\82102\anaconda3\lib\site-packages (from requests->transformers->-r requirements.txt (line 2)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\82102\anaconda3\lib\site-packages (from requests->transformers->-r requirements.txt (line 2)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\82102\anaconda3\lib\site-packages (from requests->transformers->-r requirements.txt (line 2)) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\82102\anaconda3\lib\site-packages (from jinja2->torch->-r requirements.txt (line 1)) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\82102\anaconda3\lib\site-packages (from pandas->datasets->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\82102\anaconda3\lib\site-packages (from pandas->datasets->-r requirements.txt (line 3)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\82102\anaconda3\lib\site-packages (from pandas->datasets->-r requirements.txt (line 3)) (2023.3)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\82102\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 5)) (4.0.0)

# %% [markdown]
# # Check results without any finetuning

# %%
# !python generate.py --init_from="gpt2-medium"
# Out:
# Python was not found; run without arguments to install from the Microsoft Store, or disable this shortcut from Settings > Apps > Advanced app settings > App execution aliases.

# %% [markdown]
# # Default LoRA run with rank = 128, alpha = 512

# %%
# !python train.py --init_from="gpt2-medium" --out_dir="gpt-default-lora"
# Out:
# Python was not found; run without arguments to install from the Microsoft Store, or disable this shortcut from Settings > Apps > Advanced app settings > App execution aliases.

# %% [markdown]
# # LoRA with rank = 16, alpha = 64

# %%
# !python train.py --init_from="gpt2-medium" --out_dir="gpt-r16_a64-lora" --lora_rank=16 --lora_alpha=64
# Out:
# Python was not found; run without arguments to install from the Microsoft Store, or disable this shortcut from Settings > Apps > Advanced app settings > App execution aliases.

# %% [markdown]
# # LoRA with rank = 16, alpha = 256

# %%
# !python train.py --init_from="gpt2-medium" --out_dir="gpt-r16_a256-lora" --lora_rank=16 --lora_alpha=256
# Out:
# Python was not found; run without arguments to install from the Microsoft Store, or disable this shortcut from Settings > Apps > Advanced app settings > App execution aliases.

# %% [markdown]
# # LoRA with rank = 196, alpha = 784

# %%
# !python train.py --init_from="gpt2-medium" --out_dir="gpt-r196_a784-lora" --lora_rank=196 --lora_alpha=784
# Out:
# Python was not found; run without arguments to install from the Microsoft Store, or disable this shortcut from Settings > Apps > Advanced app settings > App execution aliases.

# %% [markdown]
# # Full Finetuning with Dropout of 0.05

# %%
# !python train.py --init_from="gpt2-medium" --out_dir="gpt-r0-lora-d.05" --lora_rank=0 --dropout=.05
# Out:
# Python was not found; run without arguments to install from the Microsoft Store, or disable this shortcut from Settings > Apps > Advanced app settings > App execution aliases.
